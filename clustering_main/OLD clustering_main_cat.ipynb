# %%
import desitarget 
from desitarget.targets import desi_mask, bgs_mask, mws_mask

from astropy.table import Table
from astropy.io import fits
from astropy.cosmology import FlatLambdaCDM
import astropy.units as U

import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %%
! ls /global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/clustering/BGS*.dat.fits
# Out:
# /global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/clustering/BGS_BRIGHT-21.5_N_clustering.dat.fits
# /global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/clustering/BGS_BRIGHT-21.5_S_clustering.dat.fits
# /global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/clustering/BGS_BRIGHT_N_clustering.dat.fits
# /global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/clustering/BGS_BRIGHT_S_clustering.dat.fits

# %%
#N_raw = Table.read('/global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/clustering/BGS_N_clustering.dat.fits')

# %%
! ls -lt /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT*
# Out:
# -rw-rw---- 1 edown  desi  523820160 Nov 23 03:57 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_17_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523918080 Nov 23 03:57 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_16_clustering.ran.fits
# -rw-rw---- 1 edown  desi  524378880 Nov 23 03:56 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_15_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523696320 Nov 23 03:56 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_14_clustering.ran.fits
# -rw-rw---- 1 edown  desi  524151360 Nov 23 03:56 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_13_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523860480 Nov 23 03:56 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_12_clustering.ran.fits
# -rw-rw---- 1 edown  desi  524047680 Nov 23 03:56 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_11_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523782720 Nov 23 03:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_10_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523468800 Nov 23 03:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_9_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523480320 Nov 23 03:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_8_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523869120 Nov 23 03:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_7_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523722240 Nov 23 03:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_6_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523748160 Nov 23 03:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_5_clustering.ran.fits
# -rw-rw---- 1 edown  desi  524292480 Nov 23 03:54 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_4_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523805760 Nov 23 03:54 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_3_clustering.ran.fits
# -rw-rw---- 1 edown  desi  524082240 Nov 23 03:54 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_2_clustering.ran.fits
# -rw-rw---- 1 edown  desi  524030400 Nov 23 03:54 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_1_clustering.ran.fits
# -rw-rw---- 1 edown  desi  523932480 Nov 23 03:54 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_0_clustering.ran.fits
# -rw-rw---- 1 edown  desi   72336960 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_clustering.dat.fits
# -rw-rw---- 1 ajross desi       1875 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_nz.txt
# -rw-rw---- 1 edown  desi  318513600 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_17_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318571200 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_16_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318234240 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_15_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318792960 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_14_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318355200 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_13_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318225600 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_12_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318674880 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_11_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318136320 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_10_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318960000 Nov 23 03:53 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_9_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318922560 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_8_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318548160 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_7_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318484800 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_6_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318369600 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_5_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318571200 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_4_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318479040 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_3_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318608640 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_2_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318617280 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_1_clustering.ran.fits
# -rw-rw---- 1 edown  desi  318312000 Nov 23 03:52 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_0_clustering.ran.fits
# -rw-rw---- 1 edown  desi   44527680 Nov 23 03:51 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_clustering.dat.fits
# -rw-rw---- 1 ajross desi       1870 Nov 23 03:51 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_nz.txt
# -rw-rw---- 1 ajross desi  308923200 Oct 20 12:16 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_17_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308980800 Oct 20 12:16 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_16_clustering.ran.fits
# -rw-rw---- 1 ajross desi  309254400 Oct 20 12:16 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_15_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308851200 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_14_clustering.ran.fits
# -rw-rw---- 1 ajross desi  309119040 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_13_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308946240 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_12_clustering.ran.fits
# -rw-rw---- 1 ajross desi  309058560 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_11_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308900160 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_10_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308715840 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_9_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308724480 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_8_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308952000 Oct 20 12:15 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_7_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308865600 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_6_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308880000 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_5_clustering.ran.fits
# -rw-rw---- 1 ajross desi  309202560 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_4_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308914560 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_3_clustering.ran.fits
# -rw-rw---- 1 ajross desi  309078720 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_2_clustering.ran.fits
# -rw-rw---- 1 ajross desi  309049920 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_1_clustering.ran.fits
# -rw-rw---- 1 ajross desi  308989440 Oct 20 12:14 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_0_clustering.ran.fits
# -rw-rw---- 1 ajross desi    7709760 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_clustering.dat.fits
# -rw-rw---- 1 ajross desi       1886 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_nz.txt
# -rw-rw---- 1 ajross desi  187845120 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_17_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187879680 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_16_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187680960 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_15_clustering.ran.fits
# -rw-rw---- 1 ajross desi  188009280 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_14_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187752960 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_13_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187675200 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_12_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187940160 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_11_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187623360 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_10_clustering.ran.fits
# -rw-rw---- 1 ajross desi  188107200 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_9_clustering.ran.fits
# -rw-rw---- 1 ajross desi  188087040 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_8_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187865280 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_7_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187827840 Oct 20 12:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_6_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187761600 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_5_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187879680 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_4_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187824960 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_3_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187899840 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_2_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187905600 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_1_clustering.ran.fits
# -rw-rw---- 1 ajross desi  187727040 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_0_clustering.ran.fits
# -rw-rw---- 1 ajross desi    4193280 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_clustering.dat.fits
# -rw-rw---- 1 ajross desi       1871 Oct 20 12:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_nz.txt
# -rw-rw---- 1 ajross desi      34762 Oct 20 11:55 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHToverall_failratefit.png
# -rw-rw---- 1 ajross desi 1146867840 Oct 20 09:13 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_5_full.ran.fits
# -rw-rw---- 1 ajross desi 1147887360 Oct 20 09:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_4_full.ran.fits
# -rw-rw---- 1 ajross desi 1147104000 Oct 20 09:12 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_3_full.ran.fits
# -rw-rw---- 1 ajross desi 1147636800 Oct 20 09:11 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_2_full.ran.fits
# -rw-rw---- 1 ajross desi 1147616640 Oct 20 09:11 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_1_full.ran.fits
# -rw-rw---- 1 ajross desi 1146971520 Oct 20 09:10 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_0_full.ran.fits
# -rw-rw---- 1 ajross desi 1060986240 Oct 20 09:09 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_full.dat.fits
# -rw-rw---- 1 ajross desi 1147360320 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_16_full.ran.fits
# -rw-rw---- 1 ajross desi 1147590720 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_15_full.ran.fits
# -rw-rw---- 1 ajross desi 1147282560 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_8_full.ran.fits
# -rw-rw---- 1 ajross desi 1147317120 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_7_full.ran.fits
# -rw-rw---- 1 ajross desi 1147184640 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_17_full.ran.fits
# -rw-rw---- 1 ajross desi 1147380480 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_9_full.ran.fits
# -rw-rw---- 1 ajross desi 1147069440 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_6_full.ran.fits
# -rw-rw---- 1 ajross desi 1147423680 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_13_full.ran.fits
# -rw-rw---- 1 ajross desi 1147386240 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_14_full.ran.fits
# -rw-rw---- 1 ajross desi 1146850560 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_12_full.ran.fits
# -rw-rw---- 1 ajross desi 1146637440 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_10_full.ran.fits
# -rw-rw---- 1 ajross desi 1147703040 Oct 20 09:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_11_full.ran.fits
# -rw-rw---- 1 ajross desi  310737600 Aug 23 18:41 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_4_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  310464000 Aug 23 18:41 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_3_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  310602240 Aug 23 18:41 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_2_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  310596480 Aug 23 18:40 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_1_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  310533120 Aug 23 18:40 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_0_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi    8216640 Aug 23 18:40 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_S_clustering.MGreciso.dat.fits
# -rw-rw---- 1 ajross desi  188936640 Aug 23 18:39 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_4_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  188907840 Aug 23 18:39 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_3_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  188982720 Aug 23 18:38 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_2_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  188982720 Aug 23 18:38 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_1_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi  188792640 Aug 23 18:38 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_0_clustering.MGreciso.ran.fits
# -rw-rw---- 1 ajross desi    4455360 Aug 23 18:38 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT-21.5_N_clustering.MGreciso.dat.fits
# -rw-rw---- 1 ajross desi 1353816000 Aug 23 14:11 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_16_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353997440 Aug 23 14:10 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_17_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353248640 Aug 23 14:10 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_12_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1352989440 Aug 23 14:10 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_10_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353839040 Aug 23 14:09 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_13_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354921920 Aug 23 14:09 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_15_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354481280 Aug 23 14:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_11_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353767040 Aug 23 14:08 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_9_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354314240 Aug 23 14:07 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_14_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354331520 Aug 23 13:45 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_2_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354536000 Aug 23 13:45 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_1_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354026240 Aug 23 13:45 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_8_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353821760 Aug 23 13:45 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_6_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353862080 Aug 23 13:44 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_7_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354351680 Aug 23 13:43 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_4_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353723840 Aug 23 13:43 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_5_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1354055040 Aug 23 13:43 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_0_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1353093120 Aug 23 13:43 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_3_full_noveto.ran.fits
# -rw-rw---- 1 ajross desi 1268743680 Aug 23 13:06 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_full_noveto.dat.fits
# -rw-rw---- 1 ajross desi      33580 May 13  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_overall_failratefit.png
# -rw-rw---- 1 ajross desi       5659 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_nz.dat
# -rw-rw---- 1 ajross desi       5733 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_nz.dat
# -rw-rw---- 1 ajross desi  482016960 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_17_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482103360 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_16_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482169600 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_15_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482083200 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_14_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482077440 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_13_clustering.ran.fits
# -rw-rw---- 1 ajross desi  481826880 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_12_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482250240 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_11_clustering.ran.fits
# -rw-rw---- 1 ajross desi  481731840 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_10_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482016960 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_9_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482040000 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_8_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482051520 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_7_clustering.ran.fits
# -rw-rw---- 1 ajross desi  481944960 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_6_clustering.ran.fits
# -rw-rw---- 1 ajross desi  481844160 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_5_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482290560 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_4_clustering.ran.fits
# -rw-rw---- 1 ajross desi  481996800 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_3_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482204160 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_2_clustering.ran.fits
# -rw-rw---- 1 ajross desi  482198400 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_1_clustering.ran.fits
# -rw-rw---- 1 ajross desi  481950720 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_0_clustering.ran.fits
# -rw-rw---- 1 ajross desi   84113280 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_clustering.dat.fits
# -rw-rw---- 1 ajross desi       5814 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_nz.dat
# -rw-rw---- 1 ajross desi   49752000 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_17_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49703040 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_16_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49746240 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_15_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49703040 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_14_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49694400 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_13_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49703040 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_12_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49685760 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_11_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49584960 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_10_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49720320 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_9_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49671360 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_8_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49691520 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_7_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49610880 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_6_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49556160 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_5_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49668480 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_4_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49677120 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_3_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49734720 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_2_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49824000 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_1_clustering.ran.fits
# -rw-rw---- 1 ajross desi   49705920 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_0_clustering.ran.fits
# -rw-rw---- 1 ajross desi    8294400 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_clustering.dat.fits
# -rw-rw---- 1 ajross desi       5342 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DS_nz.dat
# -rw-rw---- 1 ajross desi  249935040 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_17_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250058880 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_16_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250248960 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_15_clustering.ran.fits
# -rw-rw---- 1 ajross desi  249906240 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_14_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250162560 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_13_clustering.ran.fits
# -rw-rw---- 1 ajross desi  249989760 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_12_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250148160 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_11_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250058880 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_10_clustering.ran.fits
# -rw-rw---- 1 ajross desi  249730560 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_9_clustering.ran.fits
# -rw-rw---- 1 ajross desi  249811200 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_8_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250018560 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_7_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250027200 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_6_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250056000 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_5_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250280640 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_4_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250009920 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_3_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250084800 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_2_clustering.ran.fits
# -rw-rw---- 1 ajross desi  249989760 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_1_clustering.ran.fits
# -rw-rw---- 1 ajross desi  250047360 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_0_clustering.ran.fits
# -rw-rw---- 1 ajross desi   44138880 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_clustering.dat.fits
# -rw-rw---- 1 ajross desi       5635 Mar 14  2022 /global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_DN_nz.dat

# %%
N = Table.read('/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_clustering.dat.fits')
S = Table.read('/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_S_clustering.dat.fits')
N['APPLIM'] = 19.539993
S['APPLIM'] = 19.5
N['ZLIM_UPPER'] = 0.6
S['ZLIM_UPPER'] = 0.6

# %%
N0 = Table.read('/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_0_clustering.ran.fits')
N4 = Table.read('/global/cfs/cdirs/desi/survey/catalogs/DA02/LSS/guadalupe/LSScats/test/BGS_BRIGHT_N_4_clustering.ran.fits')

# %%
N0.dtype.names
# Out:
# ('TARGETID',
#  'RA',
#  'DEC',
#  'NTILE',
#  'TILES',
#  'Z',
#  'WEIGHT',
#  'WEIGHT_SYS',
#  'WEIGHT_COMP',
#  'WEIGHT_ZFAIL',
#  'flux_g_dered',
#  'flux_r_dered',
#  'flux_z_dered',
#  'flux_w1_dered',
#  'flux_w2_dered',
#  'REST_GMR_0P1',
#  'KCORR_R0P1',
#  'KCORR_G0P1',
#  'KCORR_R0P0',
#  'KCORR_G0P0',
#  'REST_GMR_0P0',
#  'EQ_ALL_0P0',
#  'EQ_ALL_0P1',
#  'ABSMAG_RP0',
#  'ABSMAG_RP1',
#  'NZ',
#  'WEIGHT_FKP')

# %%
data = Table(np.hstack((N, S)))

data
# Out:
# <Table length=599200>
#      TARGETID              Z          NTILE ...   APPLIM  ZLIM_UPPER
#       int64             float64       int64 ...  float64   float64
# ----------------- ------------------- ----- ... --------- ----------
# 39633366047264297 0.16095951646742163     1 ... 19.539993        0.6
# 39633366047264412  0.2262081883049673     1 ... 19.539993        0.6
# 39633366047264710 0.20509598282456507     1 ... 19.539993        0.6
# 39633378638561503  0.3053206447975358     1 ... 19.539993        0.6
# 39633372376467396  0.2775320962351793     1 ... 19.539993        0.6
# 39633366047264487 0.10750217420934505     1 ... 19.539993        0.6
# 39633366047264069 0.23373774756268273     1 ... 19.539993        0.6
# 39633366051455429  0.2274295421540546     1 ... 19.539993        0.6
# 39633366051455137 0.10835235408674397     1 ... 19.539993        0.6
# 39633366047265345 0.23282678015147948     1 ... 19.539993        0.6
#               ...                 ...   ... ...       ...        ...
# 39628466282299967 0.17728770499156918     1 ...      19.5        0.6
# 39628466278113819 0.11315458935088593     1 ...      19.5        0.6
# 39628466278113661 0.17804082898654786     1 ...      19.5        0.6
# 39628466278113604  0.3569576609066146     1 ...      19.5        0.6
# 39628466278113439 0.17683234392145125     1 ...      19.5        0.6
# 39628466282300256 0.16054937525352278     1 ...      19.5        0.6
# 39628466282301198 0.17595966022156984     1 ...      19.5        0.6
# 39628466282301123 0.17646381737899205     1 ...      19.5        0.6
# 39628466282300416 0.17748664000550377     1 ...      19.5        0.6
# 39628466278105529 0.46072665343213026     1 ...      19.5        0.6

# %%
data.dtype.names
# Out:
# ('TARGETID',
#  'Z',
#  'NTILE',
#  'TILES',
#  'RA',
#  'DEC',
#  'WEIGHT',
#  'WEIGHT_ZFAIL',
#  'WEIGHT_COMP',
#  'WEIGHT_SYS',
#  'flux_g_dered',
#  'flux_r_dered',
#  'flux_z_dered',
#  'flux_w1_dered',
#  'flux_w2_dered',
#  'NZ',
#  'WEIGHT_FKP',
#  'REST_GMR_0P1',
#  'KCORR_R0P1',
#  'KCORR_G0P1',
#  'KCORR_R0P0',
#  'KCORR_G0P0',
#  'REST_GMR_0P0',
#  'EQ_ALL_0P0',
#  'EQ_ALL_0P1',
#  'ABSMAG_RP1',
#  'ABSMAG_RP0',
#  'APPLIM',
#  'ZLIM_UPPER')

# %%
data['z_mag'] = 22.5 - 2.5*np.log10(data['flux_z_dered'])
data['w1_mag'] = 22.5 - 2.5*np.log10(data['flux_w1_dered'])
data['g_mag'] = 22.5 - 2.5*np.log10(data['flux_g_dered'])
data['r_mag'] = 22.5 - 2.5*np.log10(data['flux_r_dered'])

N['z_mag'] = 22.5 - 2.5*np.log10(N['flux_z_dered'])
N['w1_mag'] = 22.5 - 2.5*np.log10(N['flux_w1_dered'])
N['g_mag'] = 22.5 - 2.5*np.log10(N['flux_g_dered'])
N['r_mag'] = 22.5 - 2.5*np.log10(N['flux_r_dered'])

S['z_mag'] = 22.5 - 2.5*np.log10(S['flux_z_dered'])
S['w1_mag'] = 22.5 - 2.5*np.log10(S['flux_w1_dered'])
S['g_mag'] = 22.5 - 2.5*np.log10(S['flux_g_dered'])
S['r_mag'] = 22.5 - 2.5*np.log10(S['flux_r_dered'])
# Out:
# /tmp/ipykernel_227200/3933311458.py:2: RuntimeWarning: invalid value encountered in log10
#   data['w1_mag'] = 22.5 - 2.5*np.log10(data['flux_w1_dered'])
# /tmp/ipykernel_227200/3933311458.py:7: RuntimeWarning: invalid value encountered in log10
#   N['w1_mag'] = 22.5 - 2.5*np.log10(N['flux_w1_dered'])
# /tmp/ipykernel_227200/3933311458.py:12: RuntimeWarning: invalid value encountered in log10
#   S['w1_mag'] = 22.5 - 2.5*np.log10(S['flux_w1_dered'])

# %%
plt.figure(figsize=(10,5), dpi=200)

plt.subplot(121)
plt.title('N')
plt.hist(N['r_mag'], bins=np.arange(16,22,0.01))
plt.plot([19.539993,19.539993],[0,5000], lw=0.5, color='k')
plt.ylim(0,5000)
plt.ylabel('Number')

plt.subplot(122)
plt.title('S')
plt.hist(S['r_mag'], bins=np.arange(16,22,0.01))
plt.plot([19.5,19.5],[0,5000], lw=0.5, color='k')
plt.ylim(0,5000)
plt.xlabel('Abs Mag')


plt.show()

# %%
plt.figure(figsize=(14,5),dpi=150)
plt.subplot(121)
plt.hist(N['REST_GMR_0P1'], bins=np.arange(-0.5,1.5,0.025))
plt.xlabel('REST_GMR_0P1')
plt.ylabel('number')
plt.subplot(122)
plt.hist(S['REST_GMR_0P1'], bins=np.arange(-0.5,1.5,0.025))
plt.xlabel('REST_GMR_0P1')
plt.savefig('../figures/week8-9/main_restcolour_hist.png')

# %%
print('N', np.amax(N['r_mag']))
print('S', np.amax(S['r_mag']))
# Out:
# N 19.539993
# S 19.5

# %% [markdown]
# plt.figure(figsize=(10,5), dpi=200)
# plt.plot(N_raw['RA'], N_raw['DEC'], lw=0, marker=',', label='N')
# plt.plot(S_raw['RA'], S_raw['DEC'], lw=0, marker=',', label='S')
# plt.xlabel('RA')
# plt.ylabel('DEC')
# plt.legend()
#
# plt.savefig('../figures/week6-7/DA02_sky_coverage2.png')

# %%
redshift_cut = np.where(data['Z'] <= 0.6)[0]
def zmax(m):
    return 10**(-(m+22.8)/5)

M_range = np.arange(-23,-12,0.1)
zmax_range = np.clip(zmax(M_range),a_min=None,a_max=0.6)

# %%
data[0]
# Out:
# <Row index=0>
#      TARGETID              Z          NTILE  TILES          RA               DEC              WEIGHT      WEIGHT_ZFAIL WEIGHT_COMP     WEIGHT_SYS     flux_g_dered flux_r_dered flux_z_dered flux_w1_dered flux_w2_dered          NZ              WEIGHT_FKP         REST_GMR_0P1        KCORR_R0P1          KCORR_G0P1          KCORR_R0P0          KCORR_G0P0        REST_GMR_0P0        EQ_ALL_0P0           EQ_ALL_0P1          ABSMAG_RP1          ABSMAG_RP0       APPLIM  ZLIM_UPPER   z_mag     w1_mag   g_mag     r_mag
#       int64             float64       int64 bytes11      float64           float64           float64        float32      float64        float64         float32      float32      float32       float32       float32          float64             float64             float64            float64             float64             float64             float64            float64            float64              float64             float64             float64        float64   float64    float32   float32  float32   float32
# ----------------- ------------------- ----- ------- ----------------- ----------------- ----------------- ------------ ----------- ------------------ ------------ ------------ ------------ ------------- ------------- ------------------- -------------------- ----------------- ------------------- ------------------- ------------------- ------------------- ----------------- -------------------- -------------------- ------------------ ------------------- --------- ---------- --------- --------- -------- ---------
# 39633366047264297 0.16095951646742163     1   20001 268.7008850398322 58.31651750837625 2.368794267525197    1.0202607         2.0 1.1608769635685512    7.7169294    16.809292    28.698618     21.945616     12.552565 0.01856145426373512 0.016762400045732102 0.721548822097457 -0.0480892836645471 0.07562442170381622 0.17676402087349832 0.38471493423821956 0.637311614101099 -0.15613073097339897 -0.15613073097339897 -19.01505339080518 -19.239906695343226 19.539993        0.6 18.855347 19.146631 20.28139 19.436127

# %%
fig, ax1 = plt.subplots(figsize=(7,5),dpi=200)
ax1.plot(data['ABSMAG_RP1'][redshift_cut], data['Z'][redshift_cut], lw=0, marker=',')
#¢ax1.set_yscale('log')
ax1.plot(M_range, zmax_range, label='any estimated fit', color='tab:olive')
#ax1.scatter(data['ABSMAG_RP1P1'], zmax_clipped, color='tab:red', s=0.01)
plt.ylabel('Redshift')
plt.xlabel('Abs R mag')
plt.legend()
plt.ylim(0.09,0.51)
plt.show()

# %%
plt.figure(figsize=(12,5),dpi=200)
M_range = np.arange(-25,-10,0.2)
plt.subplot(121)
plt.title('N')
plt.hist(N['ABSMAG_RP1'], bins=M_range)
plt.xlabel('Abs R mag (N)')
plt.ylabel('number')

plt.subplot(122)
plt.title('S')
plt.hist(S['ABSMAG_RP1'], bins=M_range)
plt.xlabel('Abs R mag (S)')
plt.ylabel('number')

plt.savefig('../figures/week8-9/da02_abs_rmag_hist')

# %%
Y = (data['z_mag'] - data['w1_mag']) - 1.2*(data['g_mag'] - data['r_mag']) + 1.2
plt.figure(figsize=(7,5), dpi=100)
plt.title('Bright')
plt.plot(data['r_mag'], Y, lw=0, marker=',', color='tab:blue')
plt.plot(data['r_mag'], Y, lw=0, marker=',', color='tab:blue')
plt.ylim((-1,2))
plt.xlim((17,21))
plt.ylabel('(z - W1) - 1.2(g - r) + 1.2')
plt.xlabel('r_mag')
plt.savefig('../figures/week8-9/da02_Fig4.png')

#no faint

# %%
cosmo = FlatLambdaCDM(H0=100, Om0=0.3)
data['DL'] = cosmo.luminosity_distance(np.array(data['Z']))

# %%
data
# Out:
# <Table length=599200>
#      TARGETID              Z          NTILE ...   r_mag           DL
#                                             ...                  Mpc
#       int64             float64       int64 ...  float32       float64
# ----------------- ------------------- ----- ... --------- ------------------
# 39633366047264297 0.16095951646742163     1 ... 19.436127  539.3514173803549
# 39633366047264412  0.2262081883049673     1 ... 19.377388  787.7047657932226
# 39633366047264710 0.20509598282456507     1 ... 19.354893   705.617526120866
# 39633378638561503  0.3053206447975358     1 ... 19.049171 1109.1828398978914
# 39633372376467396  0.2775320962351793     1 ...  19.32343  993.8393864610398
# 39633366047264487 0.10750217420934505     1 ... 16.959354  348.1204512009631
# 39633366047264069 0.23373774756268273     1 ... 19.360806  817.3692567569542
# 39633366051455429  0.2274295421540546     1 ... 17.736765  792.5028259710218
# 39633366051455137 0.10835235408674397     1 ... 18.692162 351.07142770523234
#               ...                 ...   ... ...       ...                ...
# 39628466282299967 0.17728770499156918     1 ... 16.302792  600.0022255538557
# 39628466278113819 0.11315458935088593     1 ... 18.384277 367.79584465673435
# 39628466278113661 0.17804082898654786     1 ... 18.431156  602.8242920810072
# 39628466278113604  0.3569576609066146     1 ... 19.318657 1330.1177958793469
# 39628466278113439 0.17683234392145125     1 ... 19.205034  598.2969661993576
# 39628466282300256 0.16054937525352278     1 ... 17.300621  537.8411726628641
# 39628466282301198 0.17595966022156984     1 ... 19.042809  595.0310997937478
# 39628466282301123 0.17646381737899205     1 ...  18.51728  596.9174665018335
# 39628466282300416 0.17748664000550377     1 ... 19.241997  600.7474549187095
# 39628466278105529 0.46072665343213026     1 ... 19.030375  1798.178119955899

# %%
data['ABSMAG_LIM'] = data['APPLIM'] - 5*np.log10(data['DL'])-25-data['KCORR_R0P1']-data['EQ_ALL_0P1']

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %%
plt.figure(dpi=200)
def find_absmag_envelope(z_range):
    if isinstance(z_range, np.ndarray):
        a = np.empty(len(z_range)-1)
        for i, z in enumerate(z_range):
            if i == len(z_range)-1:
                break
            z_close = np.where(np.logical_and(data['Z'] > (z), data['Z'] < (z_range[i+1])))[0]

            #plt.plot([zmid,zmid], [17,22])
            plt.plot(data['Z'][z_close], -data['ABSMAG_LIM'][z_close], lw=0, marker=',', label='absmaglim')

            try:
                absmag_min = np.amax(np.array(data['ABSMAG_LIM'][z_close]))
            except:
                absmag_min = np.nan
            a[i] = absmag_min
            #plt.scatter(z, -absmag_min, s=10)
        return a
    elif isinstance(z_range, float):
        z = z_range
        z_closest = find_nearest(data['Z'], z)
        print(z_closest, data['Z'][z_closest])
        z_close = np.where(np.logical_and(data['Z'] > (z-0.001), data['Z'] < (z+0.001)))[0]
        try:
            absmag_min = np.amax(np.array(data['ABSMAG_LIM'][z_close]))
        except:
            absmag_min = np.nan
        return absmag_min

z_range = np.linspace(0.1,0.5,100)        
absmag_env = find_absmag_envelope(z_range) 
plt.plot(z_range[0:-1], -absmag_env, color='plum')
plt.scatter(np.array((0.15,0.47,0.323)),-np.array((find_absmag_envelope(0.15),find_absmag_envelope(0.47),find_absmag_envelope(0.323))), s=3)
plt.xlim(0,0.6)
plt.show()
# Out:
# 195603 0.14999975607170113
# 514764 0.4700007198589736
# 368346 0.3230006227475963

# %%
plt.figure(dpi=100)
def find_k(z_range, stat):
    if isinstance(z_range, np.ndarray):
        k = np.empty(len(z_range)-1)
        for i, z in enumerate(z_range):
            if i == len(z_range)-1:
                break
            z_close = np.where(np.logical_and(data['Z'] > (z), data['Z'] < (z_range[i+1])))[0]
            plt.plot(data['Z'][z_close], data['KCORR_R0P1'][z_close], lw=0, marker=',')
            if stat == 'med':
                k[i] = np.median(data['KCORR_R0P1'][z_close])
            elif stat == 'max':
                k[i] = np.amax(data['KCORR_R0P1'][z_close])
            elif stat == 'min':
                k[i] = np.amin(data['KCORR_R0P1'][z_close])
        return k


z_range = np.linspace(0.1,0.5,100)        
k_med = find_k(z_range, 'med') 
k_max = find_k(z_range, 'max')
k_min = find_k(z_range, 'min')
plt.plot(z_range[0:-1], k_max, color='blue')
plt.plot(z_range[0:-1], k_med, color='lime')
plt.plot(z_range[0:-1], k_min, color='aqua')

plt.xlim(0,0.6)
plt.show()

# %%
z1 = find_nearest(data['Z'], 0.2)
z2 = find_nearest(data['Z'], 0.4)
e_slope = (data['EQ_ALL_0P1'][z2] - data['EQ_ALL_0P1'][z1])/(data['Z'][z2] - data['Z'][z1])
print(data['Z'][z2], data['EQ_ALL_0P1'][z2])
print(data['Z'][z1], data['EQ_ALL_0P1'][z1])
print(e_slope)

e_intercept = data['EQ_ALL_0P1'][z2] - e_slope*data['Z'][z2]
print(e_intercept)
#y = mx+c
# Out:
# 0.4000004507649722 -0.38800043724202304
# 0.1999998905457913 -0.19399989382941754
# -0.9700000000000001
# 0.0

# %%
dl_range = cosmo.luminosity_distance(z_range[0:-1]).to_value()
e_z = e_slope*z_range[0:-1] + e_intercept
faintlim_range_N_max = 19.539993 - 5*np.log10(dl_range) - 25 - k_max - e_z
faintlim_range_S_max = 19.5  - 5*np.log10(dl_range) - 25 - k_max - e_z

faintlim_range_N_min = 19.539993 - 5*np.log10(dl_range) - 25 - k_min - e_z
faintlim_range_S_min = 19.5  - 5*np.log10(dl_range) - 25 - k_min - e_z

faintlim_range_N_med = 19.539993 - 5*np.log10(dl_range) - 25 - k_med - e_z
faintlim_range_S_med = 19.5  - 5*np.log10(dl_range) - 25 - k_med - e_z

brightlim_range_max = 15 - 5*np.log10(dl_range) - 25 - k_max - e_z
brightlim_range_min = 15 - 5*np.log10(dl_range) - 25 - k_min - e_z
brightlim_range_med = 15 - 5*np.log10(dl_range) - 25 - k_med - e_z

# %%
def absmag_lim(lim0, lim1, cat):
    return np.where(np.logical_and(cat['ABSMAG_RP1'] < lim0, cat['ABSMAG_RP1'] > lim1))

def redshift_lim(lim, cat):
    return np.where(cat['Z'] < np.minimum(zmax(lim),0.6))

def redshift_lim_bright(lim, cat):
    return np.where(cat['Z'] < np.minimum(zmax_bright(lim),0.6))

def redshift_lim_from_k(lim0, lim1, cat):
    N_i = np.where(cat['APPLIM'] == 19.539993)
    S_i = np.where(cat['APPLIM'] == 19.5)
    cat['ZLIM_UPPER'][S_i] = z_range[find_nearest(faintlim_range_S_max,lim0)]
    cat['ZLIM_UPPER'][N_i] = z_range[find_nearest(faintlim_range_N_max,lim0)]

    upper_limed = np.where(cat['Z'] < np.minimum(cat['ZLIM_UPPER'],0.6))
    z_lim_lower = z_range[find_nearest(brightlim_range_min,lim1)]
    return np.intersect1d(upper_limed, np.where(cat['Z'] > z_lim_lower))

def find_zmax(M):
    z_array = []
    for m in M:
        i = find_nearest(faintlim_range_S_min, m) #ignore faintlim differences between S and N (use 19.5)
        z_array.append(z_range[i])
    return z_array
    
M_range = np.arange(-23,-16,0.01)
print(redshift_lim_from_k(-20, -21,data))

data['ZMAX'] = find_zmax(data['ABSMAG_RP1'])
# Out:
# [     0      1      2 ... 599196 599197 599198]

# %%
plt.figure(figsize=(15,5), dpi=200)

plt.subplot(131)
plt.plot(z_range[0:-1], e_z, label='linear fit', color='tab:orange', lw=4)
plt.plot(data['Z'], data['EQ_ALL_0P1'], lw=0, marker='o', color='tab:blue', markersize=0.01)
plt.legend()
plt.xlabel('Redshift')
plt.ylabel('e correction')

plt.subplot(132)
plt.plot(data['Z'], data['KCORR_R0P1'], lw=0, marker=',')
plt.plot(z_range[0:-1], k_max, color='blue', label='max k')
plt.plot(z_range[0:-1], k_med, color='lime', label='med k')
plt.plot(z_range[0:-1], k_min, color='aqua', label='min k')
plt.legend()
plt.xlabel('Redshift')
plt.ylabel('k correction')

plt.subplot(133)
plt.plot(data['Z'], -data['ABSMAG_LIM'], lw=0, marker=',')
plt.plot(z_range[0:-1], -faintlim_range_S_max, color='navy', label='faint lim, max k, S')
plt.plot(z_range[0:-1], -faintlim_range_N_max, color='cornflowerblue', label='faint lim, max k, N')
#plt.plot(z_range[0:-1], -faintlim_range_S_med, color='lime', label='med k, S')
#plt.plot(z_range[0:-1], -faintlim_range_N_med, color='palegreen', label='med k, N')
#plt.plot(z_range[0:-1], -faintlim_range_S_min, color='aqua', label='min k, S')
#plt.plot(z_range[0:-1], -faintlim_range_N_min, color='darkturquoise', label='min k, N')
plt.plot(z_range[0:-1], -brightlim_range_max, color='blue', label='bright lim, max k')
plt.plot(z_range[0:-1], -brightlim_range_min, color='lime', label='bright lim, min k')
plt.plot(z_range[0:-1], -brightlim_range_med, color='aqua', label='bright lim, med k')

plt.legend()
plt.xlabel('Redshift')
plt.ylabel('Absmag')
plt.savefig('../figures/week8-9/da02_corrections_and_absmag.png')

# %%
plt.figure(figsize=(16,5), dpi=200)
ax1 = plt.subplot(131)
ax1.plot(data['Z'], -data['ABSMAG_RP1'], lw=0, marker=',')
ax1.plot([0,0.6],[17,17], color='yellow')
ax1.plot([0,0.6],[18,18], color='cyan')
ax1.plot([0,0.6],[19,19], color='blue')
ax1.plot([0,0.6],[20,20], color='lime')
ax1.plot([0,0.6],[21,21], color='red')
ax1.plot([0,0.6],[22,22], color='magenta')
ax1.plot([0,0.6],[23,23], color='magenta')
plt.ylim(12,24)
plt.xlim(0,0.6)
plt.yticks([12,14,16,18,20,22,24],['-12','-14','-16','-18','-20','-22','-24'])
plt.xlabel('Redshift')
plt.ylabel('Absolute R magnitude')

ax2 = plt.subplot(132)
ax2.plot(data['Z'][absmag_lim(-17,-18, data)], -data['ABSMAG_RP1'][absmag_lim(-17,-18, data)], lw=0, marker=',', color='yellow')
ax2.plot(data['Z'][absmag_lim(-18,-19, data)], -data['ABSMAG_RP1'][absmag_lim(-18,-19, data)], lw=0, marker=',', color='cyan')
ax2.plot(data['Z'][absmag_lim(-19,-20, data)], -data['ABSMAG_RP1'][absmag_lim(-19,-20, data)], lw=0, marker=',', color='blue')
ax2.plot(data['Z'][absmag_lim(-20,-21, data)], -data['ABSMAG_RP1'][absmag_lim(-20,-21, data)], lw=0, marker=',', color='lime')
ax2.plot(data['Z'][absmag_lim(-21,-22, data)], -data['ABSMAG_RP1'][absmag_lim(-21,-22, data)], lw=0, marker=',', color='red')
ax2.plot(data['Z'][absmag_lim(-22,-23, data)], -data['ABSMAG_RP1'][absmag_lim(-22,-23, data)], lw=0, marker=',', color='magenta')
#ax2.plot(zmax_range, -M_range, color='tab:blue', lw=1, label='my estimate')
ax2.plot(z_range[0:-1], -faintlim_range_S_max, color='blue', label='faint lim, max k, S')
ax2.plot(z_range[0:-1], -faintlim_range_N_max, color='cornflowerblue', label='faint lim, max k, N')
#plt.plot(z_range[0:-1], -faintlim_range_S_med, color='lime', label='med k, S')

#plt.plot(z_range[0:-1], -faintlim_range_S_min, color='aqua', label='min k, S')
#plt.plot(z_range[0:-1], -brightlim_range_max, color='blue', label='bright lim, max k')
ax2.plot(z_range[0:-1], -brightlim_range_min, color='lime', label='bright lim, min k')
#plt.plot(z_range[0:-1], -brightlim_range_med, color='aqua', label='bright lim, med k')



plt.legend()
plt.yticks([])
plt.ylim(12,24)
plt.xlim(0,0.6)
plt.xlabel('Redshift')

ax3 = plt.subplot(133)
ax3.plot(data['Z'][np.intersect1d(absmag_lim(-17,-18, data), redshift_lim_from_k(-17,-18, data))], -data['ABSMAG_RP1'][np.intersect1d(absmag_lim(-17,-18, data), redshift_lim_from_k(-17,-18, data))], lw=0, marker=',', color='yellow')
ax3.plot(data['Z'][np.intersect1d(absmag_lim(-18,-19, data), redshift_lim_from_k(-18,-19, data))], -data['ABSMAG_RP1'][np.intersect1d(absmag_lim(-18,-19, data), redshift_lim_from_k(-18,-19, data))], lw=0, marker=',', color='cyan')
ax3.plot(data['Z'][np.intersect1d(absmag_lim(-19,-20, data), redshift_lim_from_k(-19,-20, data))], -data['ABSMAG_RP1'][np.intersect1d(absmag_lim(-19,-20, data), redshift_lim_from_k(-19,-20, data))], lw=0, marker=',', color='blue')
ax3.plot(data['Z'][np.intersect1d(absmag_lim(-20,-21, data), redshift_lim_from_k(-20,-21, data))], -data['ABSMAG_RP1'][np.intersect1d(absmag_lim(-20,-21, data), redshift_lim_from_k(-20,-21, data))], lw=0, marker=',', color='lime')
ax3.plot(data['Z'][np.intersect1d(absmag_lim(-21,-22, data), redshift_lim_from_k(-21,-22, data))], -data['ABSMAG_RP1'][np.intersect1d(absmag_lim(-21,-22, data), redshift_lim_from_k(-21,-22, data))], lw=0, marker=',', color='red')
ax3.plot(data['Z'][np.intersect1d(absmag_lim(-22,-23, data), redshift_lim_from_k(-22,-23, data))], -data['ABSMAG_RP1'][np.intersect1d(absmag_lim(-22,-23, data), redshift_lim_from_k(-22,-23, data))], lw=0, marker=',', color='magenta')
ax3.plot(z_range[0:-1], -faintlim_range_S_max, color='blue', label='faint lim, max k, S')
ax3.plot(z_range[0:-1], -faintlim_range_N_max, color='cornflowerblue', label='faint lim, max k, N')
ax3.plot(z_range[0:-1], -brightlim_range_min, color='lime', label='bright lim, min k')
plt.yticks([])
plt.ylim(12,24)
plt.xlim(0,0.6)

plt.xlabel('Redshift')
plt.subplots_adjust(wspace=0)
plt.savefig('../figures/week8-9/DA02_mag_v_redshift.png')

# %%
plt.figure(figsize=(12,5), dpi=200)

ax2 = plt.subplot(121)
plt.title('N')
ax2.plot(N['Z'][np.intersect1d(absmag_lim(-17,-18, N), redshift_lim_from_k(-17,-18, N))], -N['ABSMAG_RP1'][np.intersect1d(absmag_lim(-17,-18, N), redshift_lim_from_k(-17,-18, N))], lw=0, marker=',', color='yellow')
ax2.plot(N['Z'][np.intersect1d(absmag_lim(-18,-19, N), redshift_lim_from_k(-18,-19, N))], -N['ABSMAG_RP1'][np.intersect1d(absmag_lim(-18,-19, N), redshift_lim_from_k(-18,-19, N))], lw=0, marker=',', color='aqua')
ax2.plot(N['Z'][np.intersect1d(absmag_lim(-19,-20, N), redshift_lim_from_k(-19,-20, N))], -N['ABSMAG_RP1'][np.intersect1d(absmag_lim(-19,-20, N), redshift_lim_from_k(-19,-20, N))], lw=0, marker=',', color='blue')
ax2.plot(N['Z'][np.intersect1d(absmag_lim(-20,-21, N), redshift_lim_from_k(-20,-21, N))], -N['ABSMAG_RP1'][np.intersect1d(absmag_lim(-20,-21, N), redshift_lim_from_k(-20,-21, N))], lw=0, marker=',', color='lime')
ax2.plot(N['Z'][np.intersect1d(absmag_lim(-21,-22, N), redshift_lim_from_k(-21,-22, N))], -N['ABSMAG_RP1'][np.intersect1d(absmag_lim(-21,-22, N), redshift_lim_from_k(-21,-22, N))], lw=0, marker=',', color='red')
ax2.plot(N['Z'][np.intersect1d(absmag_lim(-22,-23, N), redshift_lim_from_k(-22,-23, N))], -N['ABSMAG_RP1'][np.intersect1d(absmag_lim(-22,-23, N), redshift_lim_from_k(-22,-23, N))], lw=0, marker=',', color='magenta')
#ax2.plot(zmax_range_bright, -M_range, color='tab:blue', lw=1)
ax2.plot(z_range[0:-1], -faintlim_range_N_max, color='cornflowerblue', label='faint lim, max k, N')
ax2.plot(z_range[0:-1], -brightlim_range_min, color='lime', label='bright lim, min k')
plt.yticks([])
plt.ylim(12,24)
plt.xlim(0,0.6)
plt.xlabel('Redshift')
plt.ylabel('Absolute R magnitdue (Bright)')

ax3 = plt.subplot(122)
plt.title('S')
ax3.plot(S['Z'][np.intersect1d(absmag_lim(-17,-18, S), redshift_lim_from_k(-17,-18, S))], -S['ABSMAG_RP1'][np.intersect1d(absmag_lim(-17,-18, S), redshift_lim_from_k(-17,-18, S))], lw=0, marker=',', color='yellow')
ax3.plot(S['Z'][np.intersect1d(absmag_lim(-18,-19, S), redshift_lim_from_k(-18,-19, S))], -S['ABSMAG_RP1'][np.intersect1d(absmag_lim(-18,-19, S), redshift_lim_from_k(-18,-19, S))], lw=0, marker=',', color='aqua')
ax3.plot(S['Z'][np.intersect1d(absmag_lim(-19,-20, S), redshift_lim_from_k(-19,-20, S))], -S['ABSMAG_RP1'][np.intersect1d(absmag_lim(-19,-20, S), redshift_lim_from_k(-19,-20, S))], lw=0, marker=',', color='blue')
ax3.plot(S['Z'][np.intersect1d(absmag_lim(-20,-21, S), redshift_lim_from_k(-20,-21, S))], -S['ABSMAG_RP1'][np.intersect1d(absmag_lim(-20,-21, S), redshift_lim_from_k(-20,-21, S))], lw=0, marker=',', color='lime')
ax3.plot(S['Z'][np.intersect1d(absmag_lim(-21,-22, S), redshift_lim_from_k(-21,-22, S))], -S['ABSMAG_RP1'][np.intersect1d(absmag_lim(-21,-22, S), redshift_lim_from_k(-21,-22, S))], lw=0, marker=',', color='red')
ax3.plot(S['Z'][np.intersect1d(absmag_lim(-22,-23, S), redshift_lim_from_k(-22,-23, S))], -S['ABSMAG_RP1'][np.intersect1d(absmag_lim(-22,-23, S), redshift_lim_from_k(-22,-23, S))], lw=0, marker=',', color='magenta')
#ax3.plot(zmax_range_bright, -M_range, color='tab:blue', lw=1)S
ax3.plot(z_range[0:-1], -faintlim_range_S_max, color='blue', label='faint lim, max k, S')
ax3.plot(z_range[0:-1], -brightlim_range_min, color='lime', label='bright lim, min k')
plt.yticks([])
plt.ylim(12,24)
plt.xlim(0,0.6)

plt.xlabel('Redshift')
plt.subplots_adjust(wspace=0)
plt.savefig('../figures/week8-9/main_mag_v_redshift_bright_NS.png')

# %%
plt.figure(figsize=(12,5), dpi=200)

ax1 = plt.subplot(121)
ax1.plot(N['Z'], -N['ABSMAG_RP1'], lw=0, marker=',')
plt.ylim(12,24)
plt.xlim(0,0.6)
plt.yticks([12,14,16,18,20,22,24],['-12','-14','-16','-18','-20','-22','-24'])
plt.xlabel('Redshift')
plt.ylabel('Absolute R magnitude')
plt.title('N')

ax2 = plt.subplot(122)
ax2.plot(S['Z'], -S['ABSMAG_RP1'], lw=0, marker=',')
plt.ylim(12,24)
plt.xlim(0,0.6)
plt.yticks([12,14,16,18,20,22,24],['-12','-14','-16','-18','-20','-22','-24'])
plt.xlabel('Redshift')
plt.ylabel('Absolute R magnitude')
plt.title('S')
# Out:
# Text(0.5, 1.0, 'S')

# %%
N0 = Table.read('/global/cfs/cdirs/desi/survey/catalogs/edav1/sv3/LSScats/clustering/BGS_ANY_N_0_clustering.ran.fits')
S0 = Table.read('/global/cfs/cdirs/desi/survey/catalogs/edav1/sv3/LSScats/clustering/BGS_ANY_S_0_clustering.ran.fits')

print(np.shape(N0)[0] + np.shape(S0)[0])
sky_area = 4*np.pi*np.rad2deg(1)**2
print(sky_area)
survey_area = 434393 / 2500 #randoms / deg^2
print(survey_area) # in deg^2
fsky = survey_area/sky_area
print(fsky)

A = 705.5096+1160.9628
fsky_hdr = A/sky_area
print(fsky_hdr)
# Out:
# 434393
# 41252.96124941928
# 173.7572
# 0.004211993387564293
# 0.04524456774666751

# %%
! ls /global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats
# Out:
# BGS_BRIGHT-21.5_N_nz.txt  clustering		  LRG_N_nz.txt
# BGS_BRIGHT-21.5_S_nz.txt  ELG_LOPnotqso_N_nz.txt  LRG_S_nz.txt
# BGS_BRIGHT_N_nz.txt	  ELG_LOPnotqso_S_nz.txt  QSO_N_nz.txt
# BGS_BRIGHT_S_nz.txt	  full			  QSO_S_nz.txt

# %%
with open('/global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/BGS_N_nz.txt') as file:
    print('N')
    print(file.read())

with open('/global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/BGS_S_nz.txt') as file:
    print('S')
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [45], in <module>
# ----> 1 with open('/global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/BGS_N_nz.txt') as file:
#       2     print('N')
#       3     print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/global/cfs/cdirs/desi/survey/catalogs/edav1/da02/LSScats/BGS_N_nz.txt'

# %%
z_bins = np.linspace(0,0.6,30)#np.arange(0,0.61,0.05)
plt.figure(figsize=(12,5))
plt.subplot(121)
count_N = plt.hist(N['Z'], bins=z_bins)
plt.subplot(122)
count_S = plt.hist(S['Z'], bins=z_bins)
plt.show()

# %%
number_N = count_N[0] #taget counts in redshift bins size 0.1 from 0.1 <= z <= 0.6
print(np.shape(number_N))
number_N[np.where(number_N==0.0)] = np.nan

number_S = count_S[0] #taget counts in redshift bins size 0.1 from 0.1 <= z <= 0.6
number_S[np.where(number_S==0.0)] = np.nan

# %%
#code to do this already?

def find_number_density(data, z_b):
    count = plt.hist(data['Z'], bins=z_b)
    number= count[0] #taget counts in redshift bins size 0.1 from 0.1 <= z <= 0.6
    number[np.where(number==0.0)] = np.nan
    
    vol_between = []
    for i, z in enumerate(z_b):
        if i==0:
            continue
        vol_between.append( fsky_hdr*(cosmo.comoving_volume(z_b[i]) - cosmo.comoving_volume(z_b[i-1])).to_value() )

    vol_between = np.array(vol_between)
    number_density = number/vol_between 
    return number_density

# %%
z_bins = np.arange(0.1,0.5,0.02)

n_S = find_number_density(S, z_bins)
n_N = find_number_density(N, z_bins)

# %%
plt.figure(dpi=200)
plt.plot(z_bins[1:], n_N, label='N')
plt.plot(z_bins[1:], n_S, label='S')
plt.xlabel('redshift')
plt.ylabel('number density /Mpc^3')
plt.ylim(0,0.04)
plt.legend()
plt.plot(data['Z'], data['NZ'], lw=0, marker=',')
plt.savefig('../figures/week8-9/da02_number_density.png')
#NZ column much higher

# %%
def fkp_model(n,p,comp_fac):
    return 1/(1 + n*p*comp_fac)

# %%
print(np.shape(N)[0])
print(np.sum(N['WEIGHT']))

# %%
comp_fac_N = np.shape(N)[0]/np.sum(N['WEIGHT'])
comp_fac_S = np.shape(S)[0]/np.sum(S['WEIGHT'])
fkp_model_weights_N = fkp_model(n_N, 7000, comp_fac_N) #suggested:80000 6500000000 80000**2 H0=100:60000
fkp_model_weights_S = fkp_model(n_S, 7000, comp_fac_S) #depends on no of bins - currently 30 (counted apparent no. data bins)

fig, ax = plt.subplots(figsize=(7,5),dpi=200)
plt.plot(z_bins[1:],fkp_model_weights_N, label='N', color='tab:blue')
plt.plot(z_bins[1:],fkp_model_weights_S, label='S', color='tab:orange')
plt.plot(N['Z'], N['WEIGHT_FKP'], lw=0, marker='o', markersize=0.01, color='tab:blue')
plt.plot(S['Z'], S['WEIGHT_FKP'], lw=0, marker='o', markersize=0.01, color='tab:orange')
plt.xlabel('redshift')
plt.ylabel('FKP weights')
#ax.set_yscale('log')
plt.legend()
plt.show()
#N and S different

# %% [markdown]
# 'WEIGHT',
#  'WEIGHT_ZFAIL',
#  'WEIGHT_COMP',
#  'WEIGHT_SYS',
#  'WEIGHT_FKP',

# %%
plt.figure(figsize=(16,10),dpi=150)
ax1 = plt.subplot(231)
ax1.plot(data['Z'], data['WEIGHT'], lw=0, marker='o', markersize=1)
plt.text(0.1,65,'WEIGHT = WEIGHT_SYS*WEIGHT_COMP*WEIGHT_ZFAIL', size=8)
plt.xlabel('Redshift')
plt.ylabel('Weight')
plt.ylim(0,70)

ax4 = plt.subplot(234)
ax4.plot(data['Z'], data['WEIGHT'], lw=0, marker=',')
plt.xlabel('Redshift')
plt.ylabel('Weight')
plt.ylim(0,5)

ax2 = plt.subplot(232)
ax2.plot(data['Z'], data['WEIGHT_ZFAIL'], lw=0, marker='o', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('Zfail Weight')
plt.ylim(0.995,1.029)

ax3 = plt.subplot(233)
ax3.plot(N['Z'], N['WEIGHT_FKP'], lw=0, marker='o', markersize=1)
ax3.plot(S['Z'], S['WEIGHT_FKP'], lw=0, marker='o', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('FKP Weight')
plt.ylim(0,1)

ax5 = plt.subplot(235)
ax5.plot(data['Z'], data['WEIGHT_COMP'], lw=0, marker='o', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('Completeness Weight')

ax6 = plt.subplot(236)
ax6.plot(data['Z'], data['WEIGHT_SYS'], lw=0, marker='o', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('Sys Weight')

plt.savefig('../figures/week8-9/da02_weights.png')

#https://desi.lbl.gov/trac/wiki/ClusteringWG/LSScat/DA02main/current_version#Weights
#WEIGHT = WEIGHT_SYS*WEIGHT_COMP*WEIGHT_ZFAIL

# %%
plt.figure(figsize=(12,5), dpi=200)

ax1 = plt.subplot(121)
ax1.hist(data['WEIGHT_COMP'], np.arange(0,70,0.5), label='comp')
ax1.hist(data['WEIGHT_SYS'], np.arange(0,70,0.5), label='sys')
ax1.hist(data['WEIGHT_ZFAIL'], np.arange(0,70,0.5), label='zfail')
ax1.set_yscale('log')
plt.xlabel('Weight')
plt.ylabel('Number')
plt.ylim(0.5,10**6)
plt.xlim(0,70)
plt.legend()

ax2 = plt.subplot(122)
ax2.hist(data['WEIGHT'], np.arange(0,70,0.5))
ax2.set_yscale('log')
plt.xlabel('Weight')
plt.ylabel('Number')
plt.text(15,400,'WEIGHT = WEIGHT_SYS*WEIGHT_COMP*WEIGHT_ZFAIL', size=8)
plt.ylim(0.5,10**6)
plt.xlim(0,70)

plt.savefig('../figures/week8-9/da02_weight_hist.png')

# %%
data[0:10]

# %%
N4[-1]

# %%
target_location = np.empty(10)
for i in range(0,10):
    t = N0['TARGETID'][i]
    print(t)
    #target_location[i] = np.where(N['TARGETID'] == t)[0]
print(target_location)

# %%
print(np.where(data['TARGETID'] == 327863306729553955)[0])

# %%
data['WEIGHT*FKP'] = data['WEIGHT']*data['WEIGHT_FKP']

# %%
plt.figure(figsize=(16,10),dpi=150)
ax1 = plt.subplot(231)
ax1.plot(data['Z'], data['WEIGHT*FKP'], lw=0, marker=',', markersize=1)
plt.text(0.1,12.5,'WEIGHT = WEIGHT_SYS*WEIGHT_COMP*WEIGHT_ZFAIL*WEIGHT_FKP', size=7)
plt.xlabel('Redshift')
plt.ylabel('Weight')
plt.ylim(0,20)

ax4 = plt.subplot(234)
ax4.plot(data['Z'], data['WEIGHT*FKP'], lw=0, marker=',')
plt.xlabel('Redshift')
plt.ylabel('Weight')
plt.ylim(0,2.5)

ax2 = plt.subplot(232)
ax2.plot(data['Z'], data['WEIGHT_ZFAIL'], lw=0, marker=',', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('Zfail Weight')
plt.ylim(0.995,1.029)

ax3 = plt.subplot(233)
ax3.plot(N['Z'], N['WEIGHT_FKP'], lw=0, marker=',', markersize=1)
ax3.plot(S['Z'], S['WEIGHT_FKP'], lw=0, marker=',', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('FKP Weight')
plt.ylim(0,1)

ax5 = plt.subplot(235)
ax5.plot(data['Z'], data['WEIGHT_COMP'], lw=0, marker=',', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('Completeness Weight')

ax6 = plt.subplot(236)
ax6.plot(data['Z'], data['WEIGHT_SYS'], lw=0, marker=',', markersize=1)
plt.xlabel('Redshift')
plt.ylabel('Sys Weight')

plt.show()

#https://desi.lbl.gov/trac/wiki/ClusteringWG/LSScat/DA02main/current_version#Weights
#WEIGHT = WEIGHT_SYS*WEIGHT_COMP*WEIGHT_ZFAIL

# %%
plt.figure(figsize=(12,5), dpi=200)

ax1 = plt.subplot(121)
ax1.hist(data['WEIGHT_COMP'], np.arange(0,70,0.5), label='comp')
ax1.hist(data['WEIGHT_SYS'], np.arange(0,70,0.5), label='sys')
ax1.hist(data['WEIGHT_ZFAIL'], np.arange(0,70,0.5), label='zfail')
ax1.hist(data['WEIGHT_FKP'], np.arange(0,70,0.5), label='fkp')
ax1.set_yscale('log')
plt.xlabel('Weight')
plt.ylabel('Number')
plt.ylim(0.5,10**6)
plt.xlim(0,70)
plt.legend()

ax2 = plt.subplot(122)
ax2.hist(data['WEIGHT'], np.arange(0,70,0.5))
ax2.set_yscale('log')
plt.xlabel('Weight')
plt.ylabel('Number')
plt.text(5,50000,'WEIGHT = WEIGHT_SYS*WEIGHT_COMP*WEIGHT_ZFAIL*WEIGHT_FKP', size=8)
plt.ylim(0.5,10**6)
plt.xlim(0,70)

plt.show()
