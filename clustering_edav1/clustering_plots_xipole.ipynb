# %%
from astropy.table import Table
from astropy.io import fits
import astropy.units as U

import numpy as np
import matplotlib.pyplot as plt

# %%
#columns: smid | savg | corr0(s) | corr2(s) | corr4(s) | std0(s) | std2(s) | std4(s)
#           0      1       2          3          4         5         6         7
xipoles_15log4 = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_NScomb_0.1_0.5_default_log4_njack60_nran4_split20.txt')
xipoles_15log2 = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_NScomb_0.1_0.5_default_log2_njack60_nran4_split20.txt')
xipoles_15log1 = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_NScomb_0.1_0.5_default_log1_njack60_nran4_split20.txt')

xipoles_13log2 = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_NScomb_0.1_0.3_default_log2_njack60_nran4_split20.txt')

xipoles_35log2 = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_NScomb_0.3_0.5_default_log2_njack60_nran4_split20.txt')

xipoles_15log2_N = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_N_0.1_0.5_default_log2_njack60_nran4_split20.txt')
xipoles_15log2_S = np.genfromtxt('/pscratch/sd/e/edown/outputs/outdir_xirunpc_maglim_18/smu/xipoles_BGS_ANY_S_0.1_0.5_default_log2_njack60_nran4_split20.txt')

# %%
fig, ax = plt.subplots(figsize=(20,10), dpi=150)
ax1 = plt.subplot(231)
plt.title('0.1 < z < 0.5, log4 bins')
ax1.errorbar(xipoles_15log4[:,0], xipoles_15log4[:,2], yerr=xipoles_15log4[:,5], marker='o', markersize=3, label='corr0')
ax1.errorbar(xipoles_15log4[:,0], xipoles_15log4[:,3], yerr=xipoles_15log4[:,6], marker='o', markersize=3, label='corr2')
ax1.errorbar(xipoles_15log4[:,0], xipoles_15log4[:,4], yerr=xipoles_15log4[:,7], marker='o', markersize=3, label='corr4')
ax1.set_yscale('log')
ax1.set_xscale('log')
plt.ylim(1*10**-2,80)
plt.xlabel('smid')
plt.ylabel('xipole')

ax2 = plt.subplot(232)
plt.title('0.1 < z < 0.5, log2 bins')
ax2.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,2], yerr=xipoles_15log2[:,5], marker='o', markersize=3, label='corr0')
ax2.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,3], yerr=xipoles_15log2[:,6], marker='o', markersize=3, label='corr2')
ax2.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,4], yerr=xipoles_15log2[:,7], marker='o', markersize=3, label='corr4')
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yticks([])
plt.ylim(1*10**-2,80)
plt.xlabel('smid')

ax3 = plt.subplot(233)
plt.title('0.1 < z < 0.5, log1 bins')
ax3.errorbar(xipoles_15log1[:,0], xipoles_15log1[:,2], yerr=xipoles_15log1[:,5], marker='o', markersize=3, label='corr0')
ax3.errorbar(xipoles_15log1[:,0], xipoles_15log1[:,3], yerr=xipoles_15log1[:,6], marker='o', markersize=3, label='corr2')
ax3.errorbar(xipoles_15log1[:,0], xipoles_15log1[:,4], yerr=xipoles_15log1[:,7], marker='o', markersize=3, label='corr4')
ax3.set_yscale('log')
ax3.set_xscale('log')
ax3.set_yticks([])
plt.ylim(1*10**-2,80)
plt.xlabel('smid')
plt.legend()

ax4 = plt.subplot(234)
ax4.errorbar(xipoles_15log4[:,1], xipoles_15log4[:,2], yerr=xipoles_15log4[:,5], marker='o', markersize=3, label='corr0')
ax4.errorbar(xipoles_15log4[:,1], xipoles_15log4[:,3], yerr=xipoles_15log4[:,6], marker='o', markersize=3, label='corr2')
ax4.errorbar(xipoles_15log4[:,1], xipoles_15log4[:,4], yerr=xipoles_15log4[:,7], marker='o', markersize=3, label='corr4')
ax4.set_yscale('log')
ax4.set_xscale('log')
plt.ylim(1*10**-2,80)
plt.xlabel('savg')
plt.ylabel('xipole')

ax5 = plt.subplot(235)
ax5.errorbar(xipoles_15log2[:,1], xipoles_15log2[:,2], yerr=xipoles_15log2[:,5], marker='o', markersize=3, label='corr0')
ax5.errorbar(xipoles_15log2[:,1], xipoles_15log2[:,3], yerr=xipoles_15log2[:,6], marker='o', markersize=3, label='corr2')
ax5.errorbar(xipoles_15log2[:,1], xipoles_15log2[:,4], yerr=xipoles_15log2[:,7], marker='o', markersize=3, label='corr4')
ax5.set_yscale('log')
ax5.set_xscale('log')
ax5.set_yticks([])
plt.ylim(1*10**-2,80)
plt.xlabel('savg')

ax6 = plt.subplot(236)
ax6.errorbar(xipoles_15log1[:,1], xipoles_15log1[:,2], yerr=xipoles_15log1[:,5], marker='o', markersize=3, label='corr0')
ax6.errorbar(xipoles_15log1[:,1], xipoles_15log1[:,3], yerr=xipoles_15log1[:,6], marker='o', markersize=3, label='corr2')
ax6.errorbar(xipoles_15log1[:,1], xipoles_15log1[:,4], yerr=xipoles_15log1[:,7], marker='o', markersize=3, label='corr4')
ax6.set_yscale('log')
ax6.set_xscale('log')
ax6.set_yticks([])
plt.ylim(1*10**-2,80)
plt.xlabel('savg')

plt.subplots_adjust(wspace=0)
plt.savefig('figures/week5/xipole_15log,midavg.png')

# %%
plt.figure(figsize=(20,5),dpi=150)
plt.suptitle('0.1 < z < 0.5')
ax1 = plt.subplot(131)
ax1.errorbar(xipoles_15log4[:,0], xipoles_15log4[:,2], yerr=xipoles_15log4[:,5], marker='o', markersize=3, label='log4 bins', color='steelblue')
ax1.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,2], yerr=xipoles_15log2[:,6], marker='o', markersize=3, label='log2 bins', color='deepskyblue')
ax1.errorbar(xipoles_15log1[:,0], xipoles_15log1[:,2], yerr=xipoles_15log1[:,7], marker='o', markersize=3, label='log1 bins', color='skyblue')
ax1.set_yscale('log')
plt.ylim(1*10**-2,80)
ax1.set_xscale('log')
plt.ylabel('xipole')
plt.xlabel('smid')
plt.title('corr0')
plt.legend()

ax2 = plt.subplot(132)
ax2.errorbar(xipoles_15log4[:,0], xipoles_15log4[:,3], yerr=xipoles_15log4[:,5], marker='o', markersize=3, label='log4 bins', color='darkorange')
ax2.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,3], yerr=xipoles_15log2[:,6], marker='o', markersize=3, label='log2 bins', color='orange')
ax2.errorbar(xipoles_15log1[:,0], xipoles_15log1[:,3], yerr=xipoles_15log1[:,7], marker='o', markersize=3, label='log1 bins', color='gold')
ax2.set_yscale('log')
ax2.set_yticks([])
plt.ylim(1*10**-2,80)
ax2.set_xscale('log')
plt.xlabel('smid')
plt.title('corr2')
plt.legend()


ax3 = plt.subplot(133)
ax3.errorbar(xipoles_15log4[:,0], xipoles_15log4[:,4], yerr=xipoles_15log4[:,5], marker='o', markersize=3, label='log4 bins', color='green')
ax3.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,4], yerr=xipoles_15log2[:,6], marker='o', markersize=3, label='log2 bins', color='limegreen')
ax3.errorbar(xipoles_15log1[:,0], xipoles_15log1[:,4], yerr=xipoles_15log1[:,7], marker='o', markersize=3, label='log1 bins', color='lightgreen')
ax3.set_yscale('log')
ax3.set_yticks([])
plt.ylim(1*10**-2,80)
ax3.set_xscale('log')
plt.xlabel('smid')
plt.title('corr4')
plt.legend()

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('figures/week5/xipole_15log,corrs.png')

# %%
plt.figure(figsize=(20,5),dpi=150)

ax1 = plt.subplot(131)
plt.title('0.1 < z < 0.5')
ax1.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,2], yerr=xipoles_15log2[:,5], marker='o', markersize=3, label='corr0', color='tab:blue')
ax1.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,3], yerr=xipoles_15log2[:,6], marker='o', markersize=3, label='corr2', color='tab:orange')
ax1.errorbar(xipoles_15log2[:,0], xipoles_15log2[:,4], yerr=xipoles_15log2[:,7], marker='o', markersize=3, label='corr4', color='tab:green')
ax1.set_yscale('log')
plt.ylim(1*10**-2,80)
ax1.set_xscale('log')
plt.xlabel('smid')
plt.ylabel('xipole')

ax2 = plt.subplot(132)
plt.title('0.1 < z < 0.3')
ax2.errorbar(xipoles_13log2[:,0], xipoles_13log2[:,2], yerr=xipoles_13log2[:,5], marker='o', markersize=3, label='corr0', color='tab:blue')
ax2.errorbar(xipoles_13log2[:,0], xipoles_13log2[:,3], yerr=xipoles_13log2[:,6], marker='o', markersize=3, label='corr2', color='tab:orange')
ax2.errorbar(xipoles_13log2[:,0], xipoles_13log2[:,4], yerr=xipoles_13log2[:,7], marker='o', markersize=3, label='corr4', color='tab:green')
ax2.set_yscale('log')
ax2.set_yticks([])
plt.ylim(1*10**-2,80)
ax2.set_xscale('log')
plt.xlabel('smid')

ax3 = plt.subplot(133)
plt.title('0.3 < z < 0.5')
ax3.errorbar(xipoles_35log2[:,0], xipoles_35log2[:,2], yerr=xipoles_35log2[:,5], marker='o', markersize=3, label='corr0', color='tab:blue')
ax3.errorbar(xipoles_35log2[:,0], xipoles_35log2[:,3], yerr=xipoles_35log2[:,6], marker='o', markersize=3, label='corr2', color='tab:orange')
ax3.errorbar(xipoles_35log2[:,0], xipoles_35log2[:,4], yerr=xipoles_35log2[:,7], marker='o', markersize=3, label='corr4', color='tab:green')
ax3.set_yscale('log')
ax3.set_yticks([])
plt.ylim(1*10**-2,80)
ax3.set_xscale('log')
plt.xlabel('smid')
plt.legend()

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('figures/week5/xiploe_redshiftlims.png')

# %%
plt.figure(figsize=(12,5),dpi=150)

ax1 = plt.subplot(121)
plt.title('North')
ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,2], yerr=xipoles_15log2_N[:,5], marker='o', markersize=3, label='corr0', color='tab:blue')
ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,3], yerr=xipoles_15log2_N[:,6], marker='o', markersize=3, label='corr2', color='tab:orange')
ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,4], yerr=xipoles_15log2_N[:,7], marker='o', markersize=3, label='corr4', color='tab:green')
ax1.set_yscale('log')
plt.ylim(1*10**-2,100)
ax1.set_xscale('log')
plt.xlabel('smid')
plt.ylabel('xipole')

ax2 = plt.subplot(122)
plt.title('South')
ax2.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,2], yerr=xipoles_15log2_S[:,5], marker='o', markersize=3, label='corr0', color='tab:blue')
ax2.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,3], yerr=xipoles_15log2_S[:,6], marker='o', markersize=3, label='corr2', color='tab:orange')
ax2.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,4], yerr=xipoles_15log2_S[:,7], marker='o', markersize=3, label='corr4', color='tab:green')
ax2.set_yscale('log')
ax2.set_yticks([])
plt.ylim(1*10**-2,100)
ax2.set_xscale('log')
plt.xlabel('smid')
plt.legend()

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('../figures/week5/xipole_log2_NS.png')

# %%
fig, ax1 = plt.subplots(figsize=(7,5),dpi=150)

ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,2], yerr=xipoles_15log2_N[:,5], marker='o', markersize=3, label='N, corr0', color='tab:blue')
ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,3], yerr=xipoles_15log2_N[:,6], marker='o', markersize=3, label='N, corr2', color='darkorange')
ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,4], yerr=xipoles_15log2_N[:,7], marker='o', markersize=3, label='N, corr4', color='forestgreen')

ax1.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,2], yerr=xipoles_15log2_S[:,5], marker='o', markersize=3, label='S, corr0', color='deepskyblue')
ax1.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,3], yerr=xipoles_15log2_S[:,6], marker='o', markersize=3, label='S, corr2', color='gold')
ax1.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,4], yerr=xipoles_15log2_S[:,7], marker='o', markersize=3, label='S, corr4', color='limegreen')
ax1.set_yscale('log')
plt.ylim(1*10**-2,100)
ax1.set_xscale('log')
plt.xlabel('smid')
plt.legend()

plt.savefig('../figures/week5/xipole_log2_NS_comb.png')

# %%
ylow = 1*10**-2
yhigh = 110
plt.figure(figsize=(20,5),dpi=150)
plt.suptitle('0.1 < z < 0.5')
ax1 = plt.subplot(131)
ax1.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,2], yerr=xipoles_15log2_N[:,6], marker='o', markersize=3, label='N, corr0', color='tab:blue')
ax1.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,2], yerr=xipoles_15log2_S[:,6], marker='o', markersize=3, label='S, corr0', color='deepskyblue')
ax1.set_yscale('log')
plt.ylim(ylow,yhigh)
ax1.set_xscale('log')
plt.ylabel('xipole')
plt.xlabel('smid')
plt.title('corr0')
plt.legend()

ax2 = plt.subplot(132)
ax2.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,3], yerr=xipoles_15log2_N[:,6], marker='o', markersize=3, label='N, corr2', color='darkorange')
ax2.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,3], yerr=xipoles_15log2_S[:,6], marker='o', markersize=3, label='S, corr2', color='gold')
ax2.set_yscale('log')
ax2.set_yticks([])
plt.ylim(ylow,yhigh)
ax2.set_xscale('log')
plt.xlabel('smid')
plt.title('corr2')
plt.legend()


ax3 = plt.subplot(133)
ax3.errorbar(xipoles_15log2_N[:,0], xipoles_15log2_N[:,4], yerr=xipoles_15log2_N[:,6], marker='o', markersize=3, label='N, corr4', color='forestgreen')
ax3.errorbar(xipoles_15log2_S[:,0], xipoles_15log2_S[:,4], yerr=xipoles_15log2_S[:,6], marker='o', markersize=3, label='S, corr4', color='limegreen')
ax3.set_yscale('log')
ax3.set_yticks([])
plt.ylim(ylow,yhigh)
ax3.set_xscale('log')
plt.xlabel('smid')
plt.title('corr4')
plt.legend()

plt.subplots_adjust(wspace=0,hspace=0)
plt.savefig('../figures/week5/xipole_15_log2_NS_corrs.png')
